# %%
print("Testing notebook for the real time data pipeline")
# Out:
# Testing notebook for the real time data pipeline

# %%
import logging

# %%
# Logger configuration...
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(name)s - %(message)s",
    filename="real_time_crypto_pipeline.log",
    # 'a' simply means append -- Changes are going to be writen at the end of the file...
    filemode="a"
    )

logger = logging.getLogger()

# %%
# Connect to the coinbase websocket client without auth
sanbox_websocket_url = "wss://ws-feed-public.sandbox.exchange.coinbase.com"
production_websocket_url = "wss://ws-feed.exchange.coinbase.com"

# // Request
# // Subscribe to ETH-USD and ETH-EUR with the level2, heartbeat and ticker channels,
# // plus receive the ticker entries for ETH-BTC and ETH-USD
# {
#   "type": "subscribe",
#   "product_ids": ["ETH-USD", "ETH-EUR"],
#   "channels": [
#     "level2",
#     "heartbeat",
#     {
#       "name": "ticker",
#       "product_ids": ["ETH-BTC", "ETH-USD"]
#     }
#   ]
# }

# %%
import json
import websocket
import time

sanbox_websocket_url = "wss://ws-feed-public.sandbox.exchange.coinbase.com"
production_websocket_url = "wss://ws-feed.exchange.coinbase.com"

subscribe_message = {

    "type": "subscribe",
    "product_ids": [
        "ETH-USD",
        "BTC-USD",
        "ETH-EUR",
        "BTC-EUR",

    ],
    "channels": ["ticker"]

}

# Defining the websocket event handlers...
def on_open(ws):
    try:
        logger.info("Websocket connection opened")
        # send a message when a websocket connection has been made..
        ws.send(json.dumps(subscribe_message))
        logger.info(f"subcription massage sent : {subscribe_message}")
    except Exception as e:
        logger.error(f"An error {e} trying to send the subscription message")

def on_message(ws,message):
    # receiving a stirng formatted json object and loading it into a pyrhon dictionary...
    try:
        data = json.loads(message)
        logger.info(f"Received message : {data.get('type','unknown')}")
        print(f"Message : {json.dumps(data , indent=2)} ")
    except Exception as e:
        logger.error(f"An error : {e} Occured when getting a sent message")

def on_error(ws, error):
    logger.error(f"An error : {error} occured in our websocket")
    print(f"Error:{error}")

def on_close(ws , close_status_code , close_msg):
    logger.info(f"Websocket connection closed : {close_status_code} - {close_msg}")
    print("Wesocket connection closed...")

ws = websocket.WebSocketApp(
    production_websocket_url,
    on_open=on_open,
    on_message=on_message,
    on_error=on_error,
    on_close=on_close
)

logger.info("Starting the websocket server")
ws.run_forever()
# Out:
# Message : {
#   "type": "subscriptions",
#   "channels": [
#     {
#       "name": "ticker",
#       "product_ids": [
#         "ETH-USD",
#         "BTC-USD",
#         "ETH-EUR",
#         "BTC-EUR"
#       ],
#       "account_ids": null
#     }
#   ]
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051168587,
#   "product_id": "BTC-USD",
#   "price": "93826.88",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.75544767",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.59803118",
#   "best_bid": "93824.00",
#   "best_bid_size": "1.67400722",
#   "best_ask": "93834.57",
#   "best_ask_size": "0.02073600",
#   "side": "buy",
#   "time": "2026-01-05T16:30:14.181791Z",
#   "trade_id": 931663032,
#   "last_size": "0.00009176"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 36448076111,
#   "product_id": "ETH-EUR",
#   "price": "2718.97",
#   "open_24h": "2680.42",
#   "volume_24h": "1998.21991398",
#   "low_24h": "2660.63",
#   "high_24h": "2749.42",
#   "volume_30d": "67557.02406231",
#   "best_bid": "2718.54",
#   "best_bid_size": "0.05000000",
#   "best_ask": "2718.97",
#   "best_ask_size": "0.21847860",
#   "side": "buy",
#   "time": "2026-01-05T16:30:06.586700Z",
#   "trade_id": 65495407,
#   "last_size": "0.00067647"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659344126,
#   "product_id": "ETH-USD",
#   "price": "3179.84",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.44299263",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.24877009",
#   "best_bid": "3179.80",
#   "best_bid_size": "22.44791731",
#   "best_ask": "3180.02",
#   "best_ask_size": "0.08514478",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.158258Z",
#   "trade_id": 752449451,
#   "last_size": "0.117"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 47071440982,
#   "product_id": "BTC-EUR",
#   "price": "80249.36",
#   "open_24h": "77966.26",
#   "volume_24h": "273.61470416",
#   "low_24h": "77544",
#   "high_24h": "80422.79",
#   "volume_30d": "6851.35074315",
#   "best_bid": "80220.12",
#   "best_bid_size": "0.02332147",
#   "best_ask": "80249.36",
#   "best_ask_size": "0.00142851",
#   "side": "buy",
#   "time": "2026-01-05T16:30:06.348995Z",
#   "trade_id": 102657474,
#   "last_size": "0.00000012"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051172111,
#   "product_id": "BTC-USD",
#   "price": "93836",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.75544768",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.59803119",
#   "best_bid": "93835.99",
#   "best_bid_size": "0.00000001",
#   "best_ask": "93836.00",
#   "best_ask_size": "0.01394600",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.534823Z",
#   "trade_id": 931663033,
#   "last_size": "0.00000001"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051172113,
#   "product_id": "BTC-USD",
#   "price": "93836",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.75658701",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.59917052",
#   "best_bid": "93835.99",
#   "best_bid_size": "0.00000001",
#   "best_ask": "93836.00",
#   "best_ask_size": "0.01280667",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.534823Z",
#   "trade_id": 931663034,
#   "last_size": "0.00113933"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659344734,
#   "product_id": "ETH-USD",
#   "price": "3180.02",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.44845102",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.25422848",
#   "best_bid": "3180.01",
#   "best_bid_size": "3.06232949",
#   "best_ask": "3180.02",
#   "best_ask_size": "0.23986462",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.785764Z",
#   "trade_id": 752449452,
#   "last_size": "0.00545839"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659344736,
#   "product_id": "ETH-USD",
#   "price": "3180.02",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.45537372",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.26115118",
#   "best_bid": "3180.01",
#   "best_bid_size": "3.06232949",
#   "best_ask": "3180.02",
#   "best_ask_size": "0.23294192",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.785764Z",
#   "trade_id": 752449453,
#   "last_size": "0.0069227"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659344738,
#   "product_id": "ETH-USD",
#   "price": "3180.02",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.52813741",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.33391487",
#   "best_bid": "3180.01",
#   "best_bid_size": "3.06232949",
#   "best_ask": "3180.02",
#   "best_ask_size": "0.16017823",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.785764Z",
#   "trade_id": 752449454,
#   "last_size": "0.07276369"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659344740,
#   "product_id": "ETH-USD",
#   "price": "3180.02",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.68536912",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.49114658",
#   "best_bid": "3180.01",
#   "best_bid_size": "3.06232949",
#   "best_ask": "3180.02",
#   "best_ask_size": "0.00294652",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.785764Z",
#   "trade_id": 752449455,
#   "last_size": "0.15723171"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659344742,
#   "product_id": "ETH-USD",
#   "price": "3180.02",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.68831564",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.49409310",
#   "best_bid": "3180.01",
#   "best_bid_size": "3.06232949",
#   "best_ask": "3180.08",
#   "best_ask_size": "0.03144120",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.785764Z",
#   "trade_id": 752449456,
#   "last_size": "0.00294652"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659344824,
#   "product_id": "ETH-USD",
#   "price": "3180.08",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.71975684",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.52553430",
#   "best_bid": "3180.07",
#   "best_bid_size": "3.59165509",
#   "best_ask": "3180.15",
#   "best_ask_size": "0.07862438",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.807595Z",
#   "trade_id": 752449457,
#   "last_size": "0.0314412"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659344826,
#   "product_id": "ETH-USD",
#   "price": "3180.15",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.79838122",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.60415868",
#   "best_bid": "3180.07",
#   "best_bid_size": "3.59165509",
#   "best_ask": "3180.19",
#   "best_ask_size": "0.00100000",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.807595Z",
#   "trade_id": 752449458,
#   "last_size": "0.07862438"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659345074,
#   "product_id": "ETH-USD",
#   "price": "3180.19",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.79938122",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.60515868",
#   "best_bid": "3180.18",
#   "best_bid_size": "3.06125124",
#   "best_ask": "3180.19",
#   "best_ask_size": "0.03179942",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.901411Z",
#   "trade_id": 752449459,
#   "last_size": "0.001"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659345076,
#   "product_id": "ETH-USD",
#   "price": "3180.19",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.83082242",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.63659988",
#   "best_bid": "3180.18",
#   "best_bid_size": "3.06125124",
#   "best_ask": "3180.19",
#   "best_ask_size": "0.00035822",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.901411Z",
#   "trade_id": 752449460,
#   "last_size": "0.0314412"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659345078,
#   "product_id": "ETH-USD",
#   "price": "3180.19",
#   "open_24h": "3137.89",
#   "volume_24h": "83128.83118064",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.63695810",
#   "best_bid": "3180.18",
#   "best_bid_size": "3.06125124",
#   "best_ask": "3180.33",
#   "best_ask_size": "0.29346708",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.901411Z",
#   "trade_id": 752449461,
#   "last_size": "0.00035822"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051172447,
#   "product_id": "BTC-USD",
#   "price": "93836.01",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.75658722",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.59917073",
#   "best_bid": "93836.01",
#   "best_bid_size": "0.02399156",
#   "best_ask": "93838.30",
#   "best_ask_size": "0.00130828",
#   "side": "sell",
#   "time": "2026-01-05T16:30:16.911147Z",
#   "trade_id": 931663035,
#   "last_size": "0.00000021"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659345281,
#   "product_id": "ETH-USD",
#   "price": "3180.33",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.12464772",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.93042518",
#   "best_bid": "3180.32",
#   "best_bid_size": "3.35303907",
#   "best_ask": "3180.33",
#   "best_ask_size": "0.00541622",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.963247Z",
#   "trade_id": 752449462,
#   "last_size": "0.29346708"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659345283,
#   "product_id": "ETH-USD",
#   "price": "3180.33",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.13006394",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.93584140",
#   "best_bid": "3180.32",
#   "best_bid_size": "3.35303907",
#   "best_ask": "3180.36",
#   "best_ask_size": "0.00100000",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.963247Z",
#   "trade_id": 752449463,
#   "last_size": "0.00541622"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659345287,
#   "product_id": "ETH-USD",
#   "price": "3180.36",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.13106394",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.93684140",
#   "best_bid": "3180.33",
#   "best_bid_size": "0.00026673",
#   "best_ask": "3180.37",
#   "best_ask_size": "0.03143833",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.963413Z",
#   "trade_id": 752449464,
#   "last_size": "0.001"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659345339,
#   "product_id": "ETH-USD",
#   "price": "3180.37",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.16250227",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.96827973",
#   "best_bid": "3180.36",
#   "best_bid_size": "2.90107130",
#   "best_ask": "3180.53",
#   "best_ask_size": "0.00100000",
#   "side": "buy",
#   "time": "2026-01-05T16:30:16.992461Z",
#   "trade_id": 752449465,
#   "last_size": "0.03143833"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051172858,
#   "product_id": "BTC-USD",
#   "price": "93835.99",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.75658723",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.59917074",
#   "best_bid": "93834.00",
#   "best_bid_size": "0.02250000",
#   "best_ask": "93838.30",
#   "best_ask_size": "0.00130828",
#   "side": "sell",
#   "time": "2026-01-05T16:30:17.059404Z",
#   "trade_id": 931663036,
#   "last_size": "0.00000001"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051172860,
#   "product_id": "BTC-USD",
#   "price": "93834",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.75786443",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.60044794",
#   "best_bid": "93834.00",
#   "best_bid_size": "0.02122280",
#   "best_ask": "93838.30",
#   "best_ask_size": "0.00130828",
#   "side": "sell",
#   "time": "2026-01-05T16:30:17.059404Z",
#   "trade_id": 931663037,
#   "last_size": "0.00127720"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051172914,
#   "product_id": "BTC-USD",
#   "price": "93834.01",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.75798249",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.60056600",
#   "best_bid": "93834.01",
#   "best_bid_size": "0.08475740",
#   "best_ask": "93838.30",
#   "best_ask_size": "0.00130828",
#   "side": "sell",
#   "time": "2026-01-05T16:30:17.091534Z",
#   "trade_id": 931663038,
#   "last_size": "0.00011806"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051172944,
#   "product_id": "BTC-USD",
#   "price": "93838",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.75818146",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.60076497",
#   "best_bid": "93838.00",
#   "best_bid_size": "0.02230103",
#   "best_ask": "93838.30",
#   "best_ask_size": "0.00130828",
#   "side": "sell",
#   "time": "2026-01-05T16:30:17.098596Z",
#   "trade_id": 931663039,
#   "last_size": "0.00019897"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051173684,
#   "product_id": "BTC-USD",
#   "price": "93838.18",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.76247583",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.60505934",
#   "best_bid": "93832.00",
#   "best_bid_size": "0.02250000",
#   "best_ask": "93838.18",
#   "best_ask_size": "0.03621630",
#   "side": "buy",
#   "time": "2026-01-05T16:30:17.753697Z",
#   "trade_id": 931663040,
#   "last_size": "0.00429437"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659346248,
#   "product_id": "ETH-USD",
#   "price": "3180.37",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.17747831",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608921.98325577",
#   "best_bid": "3180.36",
#   "best_bid_size": "0.46449166",
#   "best_ask": "3180.37",
#   "best_ask_size": "0.01646308",
#   "side": "buy",
#   "time": "2026-01-05T16:30:17.768113Z",
#   "trade_id": 752449466,
#   "last_size": "0.01497604"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051173727,
#   "product_id": "BTC-USD",
#   "price": "93838.18",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.76250090",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.60508441",
#   "best_bid": "93832.00",
#   "best_bid_size": "0.02250000",
#   "best_ask": "93838.18",
#   "best_ask_size": "0.03619123",
#   "side": "buy",
#   "time": "2026-01-05T16:30:17.957606Z",
#   "trade_id": 931663041,
#   "last_size": "0.00002507"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051173915,
#   "product_id": "BTC-USD",
#   "price": "93832",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.76251434",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.60509785",
#   "best_bid": "93832.00",
#   "best_bid_size": "0.02248656",
#   "best_ask": "93838.13",
#   "best_ask_size": "0.10227105",
#   "side": "sell",
#   "time": "2026-01-05T16:30:18.262679Z",
#   "trade_id": 931663042,
#   "last_size": "0.00001344"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659346524,
#   "product_id": "ETH-USD",
#   "price": "3180.39",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.33469173",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.14046919",
#   "best_bid": "3180.38",
#   "best_bid_size": "3.21263279",
#   "best_ask": "3180.47",
#   "best_ask_size": "0.03143734",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.355566Z",
#   "trade_id": 752449467,
#   "last_size": "0.15721342"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659346535,
#   "product_id": "ETH-USD",
#   "price": "3180.47",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.36612907",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.17190653",
#   "best_bid": "3180.39",
#   "best_bid_size": "0.00125824",
#   "best_ask": "3180.49",
#   "best_ask_size": "0.02381744",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.358529Z",
#   "trade_id": 752449468,
#   "last_size": "0.03143734"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659346537,
#   "product_id": "ETH-USD",
#   "price": "3180.49",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.38700043",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.19277789",
#   "best_bid": "3180.39",
#   "best_bid_size": "0.00125824",
#   "best_ask": "3180.49",
#   "best_ask_size": "0.00294608",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.358529Z",
#   "trade_id": 752449469,
#   "last_size": "0.02087136"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659346539,
#   "product_id": "ETH-USD",
#   "price": "3180.49",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.38994651",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.19572397",
#   "best_bid": "3180.39",
#   "best_bid_size": "0.00125824",
#   "best_ask": "3180.53",
#   "best_ask_size": "0.00100000",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.358529Z",
#   "trade_id": 752449470,
#   "last_size": "0.00294608"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659346541,
#   "product_id": "ETH-USD",
#   "price": "3180.53",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.39094651",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.19672397",
#   "best_bid": "3180.39",
#   "best_bid_size": "0.00125824",
#   "best_ask": "3180.70",
#   "best_ask_size": "0.00100000",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.358529Z",
#   "trade_id": 752449471,
#   "last_size": "0.001"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051174224,
#   "product_id": "BTC-USD",
#   "price": "93838.1",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.76252307",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.60510658",
#   "best_bid": "93838.00",
#   "best_bid_size": "0.02250000",
#   "best_ask": "93838.10",
#   "best_ask_size": "0.04999127",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.553929Z",
#   "trade_id": 931663043,
#   "last_size": "0.00000873"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051174256,
#   "product_id": "BTC-USD",
#   "price": "93838.1",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.76252317",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.60510668",
#   "best_bid": "93838.00",
#   "best_bid_size": "0.02250000",
#   "best_ask": "93838.10",
#   "best_ask_size": "0.04999117",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.574147Z",
#   "trade_id": 931663044,
#   "last_size": "0.00000010"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659347446,
#   "product_id": "ETH-USD",
#   "price": "3180.7",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.39194651",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.19772397",
#   "best_bid": "3180.69",
#   "best_bid_size": "1.86383672",
#   "best_ask": "3180.70",
#   "best_ask_size": "0.23245590",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.960620Z",
#   "trade_id": 752449472,
#   "last_size": "0.001"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659347448,
#   "product_id": "ETH-USD",
#   "price": "3180.7",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.39238237",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.19815983",
#   "best_bid": "3180.69",
#   "best_bid_size": "1.86383672",
#   "best_ask": "3180.70",
#   "best_ask_size": "0.23202004",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.960620Z",
#   "trade_id": 752449473,
#   "last_size": "0.00043586"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659347450,
#   "product_id": "ETH-USD",
#   "price": "3180.7",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.43576904",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.24154650",
#   "best_bid": "3180.69",
#   "best_bid_size": "1.86383672",
#   "best_ask": "3180.70",
#   "best_ask_size": "0.18863337",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.960620Z",
#   "trade_id": 752449474,
#   "last_size": "0.04338667"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659347452,
#   "product_id": "ETH-USD",
#   "price": "3180.7",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.59296714",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.39874460",
#   "best_bid": "3180.69",
#   "best_bid_size": "1.86383672",
#   "best_ask": "3180.70",
#   "best_ask_size": "0.03143527",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.960620Z",
#   "trade_id": 752449475,
#   "last_size": "0.1571981"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659347454,
#   "product_id": "ETH-USD",
#   "price": "3180.7",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.62440241",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.43017987",
#   "best_bid": "3180.69",
#   "best_bid_size": "1.86383672",
#   "best_ask": "3180.87",
#   "best_ask_size": "0.00100000",
#   "side": "buy",
#   "time": "2026-01-05T16:30:18.960620Z",
#   "trade_id": 752449476,
#   "last_size": "0.03143527"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051174733,
#   "product_id": "BTC-USD",
#   "price": "93838.01",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.76252318",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.60510669",
#   "best_bid": "93838.00",
#   "best_bid_size": "0.02250000",
#   "best_ask": "93838.09",
#   "best_ask_size": "0.11090187",
#   "side": "sell",
#   "time": "2026-01-05T16:30:19.274357Z",
#   "trade_id": 931663045,
#   "last_size": "0.00000001"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051174736,
#   "product_id": "BTC-USD",
#   "price": "93831.01",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.77104318",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.61362669",
#   "best_bid": "93830.00",
#   "best_bid_size": "0.02360000",
#   "best_ask": "93838.09",
#   "best_ask_size": "0.11090187",
#   "side": "sell",
#   "time": "2026-01-05T16:30:19.274357Z",
#   "trade_id": 931663046,
#   "last_size": "0.00852"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659348055,
#   "product_id": "ETH-USD",
#   "price": "3180.86",
#   "open_24h": "3137.89",
#   "volume_24h": "83129.76971241",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.57548987",
#   "best_bid": "3180.86",
#   "best_bid_size": "1.49598137",
#   "best_ask": "3180.87",
#   "best_ask_size": "0.44502076",
#   "side": "sell",
#   "time": "2026-01-05T16:30:19.279079Z",
#   "trade_id": 752449477,
#   "last_size": "0.14531"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659348057,
#   "product_id": "ETH-USD",
#   "price": "3180.86",
#   "open_24h": "3137.89",
#   "volume_24h": "83130.00824241",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.81401987",
#   "best_bid": "3180.86",
#   "best_bid_size": "1.25745137",
#   "best_ask": "3180.87",
#   "best_ask_size": "0.44502076",
#   "side": "sell",
#   "time": "2026-01-05T16:30:19.279079Z",
#   "trade_id": 752449478,
#   "last_size": "0.23853"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659348059,
#   "product_id": "ETH-USD",
#   "price": "3180.86",
#   "open_24h": "3137.89",
#   "volume_24h": "83130.12540241",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608922.93117987",
#   "best_bid": "3180.86",
#   "best_bid_size": "1.14029137",
#   "best_ask": "3180.87",
#   "best_ask_size": "0.44502076",
#   "side": "sell",
#   "time": "2026-01-05T16:30:19.279079Z",
#   "trade_id": 752449479,
#   "last_size": "0.11716"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659348064,
#   "product_id": "ETH-USD",
#   "price": "3180.86",
#   "open_24h": "3137.89",
#   "volume_24h": "83130.71840241",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608923.52417987",
#   "best_bid": "3180.86",
#   "best_bid_size": "0.54729137",
#   "best_ask": "3180.87",
#   "best_ask_size": "0.44502076",
#   "side": "sell",
#   "time": "2026-01-05T16:30:19.279259Z",
#   "trade_id": 752449480,
#   "last_size": "0.593"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659348068,
#   "product_id": "ETH-USD",
#   "price": "3180.86",
#   "open_24h": "3137.89",
#   "volume_24h": "83131.26569378",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.07147124",
#   "best_bid": "3180.60",
#   "best_bid_size": "0.66200000",
#   "best_ask": "3180.87",
#   "best_ask_size": "0.44502076",
#   "side": "sell",
#   "time": "2026-01-05T16:30:19.279481Z",
#   "trade_id": 752449481,
#   "last_size": "0.54729137"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051175129,
#   "product_id": "BTC-USD",
#   "price": "93824.27",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.97104318",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.81362669",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.01313782",
#   "best_ask": "93830.01",
#   "best_ask_size": "0.17972000",
#   "side": "sell",
#   "time": "2026-01-05T16:30:19.312621Z",
#   "trade_id": 931663047,
#   "last_size": "0.2"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051175666,
#   "product_id": "BTC-USD",
#   "price": "93824.27",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.97104339",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.81362690",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.01313761",
#   "best_ask": "93824.28",
#   "best_ask_size": "0.15039928",
#   "side": "sell",
#   "time": "2026-01-05T16:30:19.612549Z",
#   "trade_id": 931663048,
#   "last_size": "0.00000021"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051175759,
#   "product_id": "BTC-USD",
#   "price": "93824.28",
#   "open_24h": "91279.99",
#   "volume_24h": "8274.97104353",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.81362704",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.01313761",
#   "best_ask": "93824.28",
#   "best_ask_size": "0.15041374",
#   "side": "buy",
#   "time": "2026-01-05T16:30:19.751148Z",
#   "trade_id": 931663049,
#   "last_size": "0.00000014"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349265,
#   "product_id": "ETH-USD",
#   "price": "3180.21",
#   "open_24h": "3137.89",
#   "volume_24h": "83131.28983899",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.09561645",
#   "best_bid": "3180.20",
#   "best_bid_size": "21.19152163",
#   "best_ask": "3180.21",
#   "best_ask_size": "0.00729599",
#   "side": "buy",
#   "time": "2026-01-05T16:30:19.877613Z",
#   "trade_id": 752449482,
#   "last_size": "0.02414521"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349507,
#   "product_id": "ETH-USD",
#   "price": "3180.21",
#   "open_24h": "3137.89",
#   "volume_24h": "83131.29713498",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.10291244",
#   "best_bid": "3180.20",
#   "best_bid_size": "21.19146186",
#   "best_ask": "3180.29",
#   "best_ask_size": "0.15721836",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.342445Z",
#   "trade_id": 752449483,
#   "last_size": "0.00729599"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349509,
#   "product_id": "ETH-USD",
#   "price": "3180.29",
#   "open_24h": "3137.89",
#   "volume_24h": "83131.45435334",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.26013080",
#   "best_bid": "3180.20",
#   "best_bid_size": "21.19146186",
#   "best_ask": "3180.48",
#   "best_ask_size": "0.00098911",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.342445Z",
#   "trade_id": 752449484,
#   "last_size": "0.15721836"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349881,
#   "product_id": "ETH-USD",
#   "price": "3180.48",
#   "open_24h": "3137.89",
#   "volume_24h": "83131.45534245",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.26111991",
#   "best_bid": "3180.47",
#   "best_bid_size": "1.65147000",
#   "best_ask": "3180.48",
#   "best_ask_size": "0.21322057",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.467505Z",
#   "trade_id": 752449485,
#   "last_size": "0.00098911"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349883,
#   "product_id": "ETH-USD",
#   "price": "3180.48",
#   "open_24h": "3137.89",
#   "volume_24h": "83131.61255142",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.41832888",
#   "best_bid": "3180.47",
#   "best_bid_size": "1.65147000",
#   "best_ask": "3180.48",
#   "best_ask_size": "0.05601160",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.467505Z",
#   "trade_id": 752449486,
#   "last_size": "0.15720897"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349885,
#   "product_id": "ETH-USD",
#   "price": "3180.48",
#   "open_24h": "3137.89",
#   "volume_24h": "83131.64399084",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.44976830",
#   "best_bid": "3180.47",
#   "best_bid_size": "1.65147000",
#   "best_ask": "3180.48",
#   "best_ask_size": "0.02457218",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.467505Z",
#   "trade_id": 752449487,
#   "last_size": "0.03143942"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349887,
#   "product_id": "ETH-USD",
#   "price": "3180.48",
#   "open_24h": "3137.89",
#   "volume_24h": "83131.65409980",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.45987726",
#   "best_bid": "3180.47",
#   "best_bid_size": "1.65147000",
#   "best_ask": "3180.48",
#   "best_ask_size": "0.01446322",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.467505Z",
#   "trade_id": 752449488,
#   "last_size": "0.01010896"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349889,
#   "product_id": "ETH-USD",
#   "price": "3180.48",
#   "open_24h": "3137.89",
#   "volume_24h": "83131.66856302",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.47434048",
#   "best_bid": "3180.47",
#   "best_bid_size": "1.65147000",
#   "best_ask": "3180.49",
#   "best_ask_size": "0.50000000",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.467505Z",
#   "trade_id": 752449489,
#   "last_size": "0.01446322"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349891,
#   "product_id": "ETH-USD",
#   "price": "3180.49",
#   "open_24h": "3137.89",
#   "volume_24h": "83132.16856302",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.97434048",
#   "best_bid": "3180.47",
#   "best_bid_size": "1.65147000",
#   "best_ask": "3180.51",
#   "best_ask_size": "0.00015751",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.467505Z",
#   "trade_id": 752449490,
#   "last_size": "0.5"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349893,
#   "product_id": "ETH-USD",
#   "price": "3180.51",
#   "open_24h": "3137.89",
#   "volume_24h": "83132.16872053",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.97449799",
#   "best_bid": "3180.47",
#   "best_bid_size": "1.65147000",
#   "best_ask": "3180.59",
#   "best_ask_size": "0.00021793",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.467505Z",
#   "trade_id": 752449491,
#   "last_size": "0.00015751"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659349912,
#   "product_id": "ETH-USD",
#   "price": "3180.59",
#   "open_24h": "3137.89",
#   "volume_24h": "83132.16893846",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608924.97471592",
#   "best_bid": "3180.48",
#   "best_bid_size": "0.21417000",
#   "best_ask": "3180.84",
#   "best_ask_size": "0.07860732",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.471009Z",
#   "trade_id": 752449492,
#   "last_size": "0.00021793"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051176337,
#   "product_id": "BTC-USD",
#   "price": "93824.28",
#   "open_24h": "91279.99",
#   "volume_24h": "8275.02104270",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.86362621",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.10435959",
#   "best_ask": "93824.28",
#   "best_ask_size": "0.00001461",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.470514Z",
#   "trade_id": 931663050,
#   "last_size": "0.04999917"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051176339,
#   "product_id": "BTC-USD",
#   "price": "93824.28",
#   "open_24h": "91279.99",
#   "volume_24h": "8275.02105730",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.86364081",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.10435959",
#   "best_ask": "93824.28",
#   "best_ask_size": "0.00000001",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.470514Z",
#   "trade_id": 931663051,
#   "last_size": "0.0000146"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051176341,
#   "product_id": "BTC-USD",
#   "price": "93824.28",
#   "open_24h": "91279.99",
#   "volume_24h": "8275.02105731",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.86364082",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.10435959",
#   "best_ask": "93824.30",
#   "best_ask_size": "0.05000000",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.470514Z",
#   "trade_id": 931663052,
#   "last_size": "0.00000001"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051176343,
#   "product_id": "BTC-USD",
#   "price": "93824.3",
#   "open_24h": "91279.99",
#   "volume_24h": "8275.06447391",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.90705742",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.10435959",
#   "best_ask": "93824.30",
#   "best_ask_size": "0.00658340",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.470514Z",
#   "trade_id": 931663053,
#   "last_size": "0.04341660"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051176349,
#   "product_id": "BTC-USD",
#   "price": "93824.3",
#   "open_24h": "91279.99",
#   "volume_24h": "8275.07105731",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.91364082",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.03732959",
#   "best_ask": "93826.81",
#   "best_ask_size": "0.04079060",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.474345Z",
#   "trade_id": 931663054,
#   "last_size": "0.00658340"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051176351,
#   "product_id": "BTC-USD",
#   "price": "93826.81",
#   "open_24h": "91279.99",
#   "volume_24h": "8275.10526451",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.94784802",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.03732959",
#   "best_ask": "93826.81",
#   "best_ask_size": "0.00658340",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.474345Z",
#   "trade_id": 931663055,
#   "last_size": "0.03420720"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051176354,
#   "product_id": "BTC-USD",
#   "price": "93826.81",
#   "open_24h": "91279.99",
#   "volume_24h": "8275.11184791",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.95443142",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.03732959",
#   "best_ask": "93833.94",
#   "best_ask_size": "0.00010196",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.474397Z",
#   "trade_id": 931663056,
#   "last_size": "0.00658340"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659350289,
#   "product_id": "ETH-USD",
#   "price": "3180.84",
#   "open_24h": "3137.89",
#   "volume_24h": "83132.24754578",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608925.05332324",
#   "best_bid": "3180.83",
#   "best_bid_size": "0.30433000",
#   "best_ask": "3180.84",
#   "best_ask_size": "0.03143581",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.577394Z",
#   "trade_id": 752449493,
#   "last_size": "0.07860732"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659350291,
#   "product_id": "ETH-USD",
#   "price": "3180.84",
#   "open_24h": "3137.89",
#   "volume_24h": "83132.27898159",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608925.08475905",
#   "best_bid": "3180.83",
#   "best_bid_size": "0.30433000",
#   "best_ask": "3180.87",
#   "best_ask_size": "0.00100000",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.577394Z",
#   "trade_id": 752449494,
#   "last_size": "0.03143581"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659350293,
#   "product_id": "ETH-USD",
#   "price": "3180.87",
#   "open_24h": "3137.89",
#   "volume_24h": "83132.27998159",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608925.08575905",
#   "best_bid": "3180.83",
#   "best_bid_size": "0.30433000",
#   "best_ask": "3180.89",
#   "best_ask_size": "0.07860621",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.577394Z",
#   "trade_id": 752449495,
#   "last_size": "0.001"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659350295,
#   "product_id": "ETH-USD",
#   "price": "3180.89",
#   "open_24h": "3137.89",
#   "volume_24h": "83132.35858780",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608925.16436526",
#   "best_bid": "3180.83",
#   "best_bid_size": "0.30433000",
#   "best_ask": "3181.04",
#   "best_ask_size": "0.00100000",
#   "side": "buy",
#   "time": "2026-01-05T16:30:20.577394Z",
#   "trade_id": 752449496,
#   "last_size": "0.07860621"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 91659352101,
#   "product_id": "ETH-USD",
#   "price": "3180.59",
#   "open_24h": "3137.89",
#   "volume_24h": "83132.39401680",
#   "low_24h": "3117.71",
#   "high_24h": "3219.21",
#   "volume_30d": "2608925.19979426",
#   "best_bid": "3180.58",
#   "best_bid_size": "0.00138170",
#   "best_ask": "3180.59",
#   "best_ask_size": "1.31185453",
#   "side": "buy",
#   "time": "2026-01-05T16:30:21.900724Z",
#   "trade_id": 752449497,
#   "last_size": "0.035429"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051178546,
#   "product_id": "BTC-USD",
#   "price": "93829.98",
#   "open_24h": "91279.99",
#   "volume_24h": "8275.11184792",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.95443143",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.01313761",
#   "best_ask": "93829.99",
#   "best_ask_size": "0.13503927",
#   "side": "sell",
#   "time": "2026-01-05T16:30:22.066160Z",
#   "trade_id": 931663057,
#   "last_size": "0.00000001"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 119051178548,
#   "product_id": "BTC-USD",
#   "price": "93824.27",
#   "open_24h": "91279.99",
#   "volume_24h": "8275.11184812",
#   "low_24h": "90827.3",
#   "high_24h": "94078",
#   "volume_30d": "191197.95443163",
#   "best_bid": "93824.27",
#   "best_bid_size": "0.01313741",
#   "best_ask": "93829.99",
#   "best_ask_size": "0.13503927",
#   "side": "sell",
#   "time": "2026-01-05T16:30:22.066160Z",
#   "trade_id": 931663058,
#   "last_size": "0.00000020"
# }
# Message : {
#   "type": "ticker",
#   "sequence": 47071453670,
#   "product_id": "BTC-EUR",
#   "price": "80199.54",
#   "open_24h": "77966.26",
#   "volume_24h": "273.61489371",
#   "low_24h": "77544",
#   "high_24h": "80422.79",
#   "volume_30d": "6851.35093270",
#   "best_bid": "80199.54",
#   "best_bid_size": "0.01036828",
#   "best_ask": "80224.65",
#   "best_ask_size": "0.01123012",
#   "side": "sell",
#   "time": "2026-01-05T16:30:22.469315Z",
#   "trade_id": 102657475,
#   "last_size": "0.00018955"
# }
# Error:
# Wensocket connection closed...
# True
